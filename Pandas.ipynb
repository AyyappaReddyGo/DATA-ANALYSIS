# %%
import pandas as pd
a=["jwalitha",'Ramya','Durga','jahnavi','Lahari','Sunny','Danush']
r=pd.Series(a,index=[67,43,44,89,34,45,23])
print(r)
# Out:
# 67    jwalitha
# 43       Ramya
# 44       Durga
# 89     jahnavi
# 34      Lahari
# 45       Sunny
# 23      Danush
# dtype: object

# %%
df=pd.read_csv("/content/diabetcsv.csv")
print(df)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
df=pd.read_csv("/content/grades_withnulls.csv",sep=" ")
print(df)
# Out:
#    Names,Initials,SEM1,SEM2,SEM3,Grade,Placed
# 0                       Joe,K,9.8,10,9.9,A+,1
# 1                    Rajesh,M,8.9,9.1,9.3,A,1
# 2                     Kissan,V,9.9,9.8,10,A,0
# 3                        Mary,N,7.7,8,NaN,B,0
# 4                     Jeen,K,9.8,9.1,9.9,A+,1
# 5                       Raj,M,8.9,9.1,9.3,A,1
# 6                      Hassan,V,9.9,9,9.2,A,1
# 7                        Mari,N,7.7,8,7.1,B,1
# 8                     Jess,K,NaN,9.1,9.9,A+,1
# 9                    Rajini,M,NaN,9.1,9.3,A,0
# 10                    Kiran,V,NaN,9.3,9.2,A,0
# 11                       Maya,N,7.7,8,7.1,B,0
# 12                   Jolin,K,9.8,9.1,9.9,A+,1
# 13                   Rajesh,M,8.9,9.1,9.3,A,1
# 14                      Riya,M,9.3,9.9,10,A,1
# 15                     Sana,V,9.9,9.3,9.2,A,0
# 16                         Mark,N,7.7,8,7,B,0

# %%
import pandas as pd
df=pd.read_excel("/content/diabet.xlsx.xlsx")
print(df)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
import pandas as pd
df=pd.read_excel("/content/diabet.xlsx.xlsx",sheet_name=0)
print(df)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
import pandas as pd
df=pd.read_excel("/content/diabet.xlsx.xlsx")
print(df.head())
print(df.tail(n=10))
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 758     1   106    76     0     0  37.5  0.197   26  tested_negative
# 759     6   190    92     0     0  35.5  0.278   66  tested_positive
# 760     2    88    58    26    16  28.4  0.766   22  tested_negative
# 761     9   170    74    31     0  44.0  0.403   43  tested_positive
# 762     9    89    62     0     0  22.5  0.142   33  tested_negative
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative

# %%
df=pd.read_excel("/content/diabet.xlsx.xlsx")
print(df.describe)
# Out:
# <bound method NDFrame.describe of      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]>

# %%
df=pd.read_excel("/content/diabet.xlsx.xlsx")
print(df.describe().T)
# Out:
#       count        mean         std     min       25%       50%        75%  \
# preg  768.0    3.845052    3.369578   0.000   1.00000    3.0000    6.00000
# plas  768.0  120.894531   31.972618   0.000  99.00000  117.0000  140.25000
# pres  768.0   69.105469   19.355807   0.000  62.00000   72.0000   80.00000
# skin  768.0   20.536458   15.952218   0.000   0.00000   23.0000   32.00000
# insu  768.0   79.799479  115.244002   0.000   0.00000   30.5000  127.25000
# mass  768.0   31.992578    7.884160   0.000  27.30000   32.0000   36.60000
# pedi  768.0    0.471876    0.331329   0.078   0.24375    0.3725    0.62625
# age   768.0   33.240885   11.760232  21.000  24.00000   29.0000   41.00000
#
#          max
# preg   17.00
# plas  199.00
# pres  122.00
# skin   99.00
# insu  846.00
# mass   67.10
# pedi    2.42
# age    81.00

# %%
df=pd.read_excel("/content/diabet.xlsx.xlsx")
print(df.shape)
print(df.shape[0])
print(df.shape[1])
# Out:
# (768, 9)
# 768
# 9

# %%
df=pd.read_excel("/content/diabet.xlsx.xlsx")
print(df.columns)
l1=list(df.columns)
print(l1)
# Out:
# Index(['preg', 'plas', 'pres', 'skin', 'insu', 'mass', 'pedi', 'age', 'class'], dtype='object')
# ['preg', 'plas', 'pres', 'skin', 'insu', 'mass', 'pedi', 'age', 'class']

# %%
df=pd.read_excel("/content/diabet.xlsx.xlsx")
df2=df.copy()
df2.loc[2:5,'preg']=None
df2.head(7)
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0   6.0   148    72    35     0  33.6  0.627   50  tested_positive
# 1   1.0    85    66    29     0  26.6  0.351   31  tested_negative
# 2   NaN   183    64     0     0  23.3  0.672   32  tested_positive
# 3   NaN    89    66    23    94  28.1  0.167   21  tested_negative
# 4   NaN   137    40    35   168  43.1  2.288   33  tested_positive
# 5   NaN   116    74     0     0  25.6  0.201   30  tested_negative
# 6   3.0    78    50    32    88  31.0  0.248   26  tested_positive

# %%
df2.isnull().head(7)
# Out:
#     preg   plas   pres   skin   insu   mass   pedi    age  class
# 0  False  False  False  False  False  False  False  False  False
# 1  False  False  False  False  False  False  False  False  False
# 2   True  False  False  False  False  False  False  False  False
# 3   True  False  False  False  False  False  False  False  False
# 4   True  False  False  False  False  False  False  False  False
# 5   True  False  False  False  False  False  False  False  False
# 6  False  False  False  False  False  False  False  False  False

# %%
df2.isnull().tail(7)
# Out:
#       preg   plas   pres   skin   insu   mass   pedi    age  class
# 761  False  False  False  False  False  False  False  False  False
# 762  False  False  False  False  False  False  False  False  False
# 763  False  False  False  False  False  False  False  False  False
# 764  False  False  False  False  False  False  False  False  False
# 765  False  False  False  False  False  False  False  False  False
# 766  False  False  False  False  False  False  False  False  False
# 767  False  False  False  False  False  False  False  False  False

# %%
df2.isnull().sum()
# Out:
# preg     4
# plas     0
# pres     0
# skin     0
# insu     0
# mass     0
# pedi     0
# age      0
# class    0
# dtype: int64

# %%
print(df['preg'])
# Out:
# 0       6
# 1       1
# 2       8
# 3       1
# 4       0
#        ..
# 763    10
# 764     2
# 765     5
# 766     1
# 767     1
# Name: preg, Length: 768, dtype: int64

# %%
print(df2[['preg','age']])
# Out:
#      preg  age
# 0     6.0   50
# 1     1.0   31
# 2     NaN   32
# 3     NaN   21
# 4     NaN   33
# ..    ...  ...
# 763  10.0   63
# 764   2.0   27
# 765   5.0   30
# 766   1.0   47
# 767   1.0   23
#
# [768 rows x 2 columns]

# %%
print(df[df.index.isin(range(2,5))])
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
print(df2.loc[1])
# Out:
# preg                 1.0
# plas                  85
# pres                  66
# skin                  29
# insu                   0
# mass                26.6
# pedi               0.351
# age                   31
# class    tested_negative
# Name: 1, dtype: object

# %%
print(df2.loc[3])
# Out:
# preg                 NaN
# plas                  89
# pres                  66
# skin                  23
# insu                  94
# mass                28.1
# pedi               0.167
# age                   21
# class    tested_negative
# Name: 3, dtype: object

# %%
df2.loc[6:11]
# Out:
#     preg  plas  pres  skin  insu  mass   pedi  age            class
# 6    3.0    78    50    32    88  31.0  0.248   26  tested_positive
# 7   10.0   115     0     0     0  35.3  0.134   29  tested_negative
# 8    2.0   197    70    45   543  30.5  0.158   53  tested_positive
# 9    8.0   125    96     0     0   0.0  0.232   54  tested_positive
# 10   4.0   110    92     0     0  37.6  0.191   30  tested_negative
# 11  10.0   168    74     0     0  38.0  0.537   34  tested_positive

# %%
df2.loc[6:11,'preg']==None
print(df2)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6.0   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1.0    85    66    29     0  26.6  0.351   31  tested_negative
# 2     NaN   183    64     0     0  23.3  0.672   32  tested_positive
# 3     NaN    89    66    23    94  28.1  0.167   21  tested_negative
# 4     NaN   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763  10.0   101    76    48   180  32.9  0.171   63  tested_negative
# 764   2.0   122    70    27     0  36.8  0.340   27  tested_negative
# 765   5.0   121    72    23   112  26.2  0.245   30  tested_negative
# 766   1.0   126    60     0     0  30.1  0.349   47  tested_positive
# 767   1.0    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
df2.loc[10:15,['preg','age']]
# Out:
#     preg  age
# 10   4.0   30
# 11  10.0   34
# 12  10.0   57
# 13   1.0   59
# 14   5.0   51
# 15   7.0   32

# %%
df2.loc[:7,['preg']]
# Out:
#    preg
# 0   6.0
# 1   1.0
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   3.0
# 7  10.0

# %%
df2.iloc[6:11,:3]
# Out:
#     preg  plas  pres
# 6    3.0    78    50
# 7   10.0   115     0
# 8    2.0   197    70
# 9    8.0   125    96
# 10   4.0   110    92

# %%
df2.loc[df['preg']==6.0]
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6.0   148    72    35     0  33.6  0.627   50  tested_positive
# 33    6.0    92    92     0     0  19.9  0.188   28  tested_negative
# 95    6.0   144    72    27   228  33.9  0.255   40  tested_negative
# 98    6.0    93    50    30    64  28.7  0.356   23  tested_negative
# 121   6.0   111    64    39     0  34.2  0.260   24  tested_negative
# 165   6.0   104    74    18   156  29.9  0.722   41  tested_positive
# 170   6.0   102    82     0     0  30.8  0.180   36  tested_positive
# 171   6.0   134    70    23   130  35.4  0.542   29  tested_positive
# 176   6.0    85    78     0     0  31.2  0.382   42  tested_negative
# 180   6.0    87    80     0     0  23.2  0.084   32  tested_negative
# 204   6.0   103    72    32   190  37.7  0.324   55  tested_negative
# 217   6.0   125    68    30   120  30.0  0.464   32  tested_negative
# 231   6.0   134    80    37   370  46.2  0.238   46  tested_positive
# 243   6.0   119    50    22   176  27.1  1.318   33  tested_positive
# 295   6.0   151    62    31   120  35.5  0.692   28  tested_negative
# 310   6.0    80    66    30     0  26.2  0.313   41  tested_negative
# 319   6.0   194    78     0     0  23.5  0.129   59  tested_positive
# 329   6.0   105    70    32    68  30.8  0.122   37  tested_negative
# 366   6.0   124    72     0     0  27.6  0.368   29  tested_positive
# 401   6.0   137    61     0     0  24.2  0.151   55  tested_negative
# 410   6.0   102    90    39     0  35.7  0.674   28  tested_negative
# 439   6.0   107    88     0     0  36.8  0.727   31  tested_negative
# 469   6.0   154    78    41   140  46.1  0.571   27  tested_negative
# 495   6.0   166    74     0     0  26.6  0.304   66  tested_negative
# 499   6.0   154    74    32   193  29.3  0.839   39  tested_negative
# 502   6.0     0    68    41     0  39.0  0.727   41  tested_positive
# 519   6.0   129    90     7   326  19.6  0.582   60  tested_negative
# 522   6.0   114     0     0     0   0.0  0.189   26  tested_negative
# 533   6.0    91     0     0     0  29.8  0.501   31  tested_negative
# 552   6.0   114    88     0     0  27.8  0.247   66  tested_negative
# 560   6.0   125    76     0     0  33.8  0.121   54  tested_positive
# 563   6.0    99    60    19    54  26.9  0.497   32  tested_negative
# 567   6.0    92    62    32   126  32.0  0.085   46  tested_negative
# 576   6.0   108    44    20   130  24.0  0.813   35  tested_negative
# 581   6.0   109    60    27     0  25.0  0.206   27  tested_negative
# 587   6.0   103    66     0     0  24.3  0.249   29  tested_negative
# 594   6.0   123    72    45   230  33.6  0.733   34  tested_negative
# 601   6.0    96     0     0     0  23.7  0.190   28  tested_negative
# 613   6.0   105    80    28     0  32.5  0.878   26  tested_negative
# 616   6.0   117    96     0     0  28.7  0.157   30  tested_negative
# 622   6.0   183    94     0     0  40.8  1.461   45  tested_negative
# 642   6.0   147    80     0     0  29.5  0.178   50  tested_positive
# 664   6.0   115    60    39     0  33.7  0.245   40  tested_positive
# 668   6.0    98    58    33   190  34.0  0.430   43  tested_negative
# 670   6.0   165    68    26   168  33.6  0.631   49  tested_negative
# 675   6.0   195    70     0     0  30.9  0.328   31  tested_positive
# 701   6.0   125    78    31     0  27.6  0.565   49  tested_positive
# 705   6.0    80    80    36     0  39.8  0.177   28  tested_negative
# 749   6.0   162    62     0     0  24.3  0.178   50  tested_positive
# 759   6.0   190    92     0     0  35.5  0.278   66  tested_positive

# %%
df.loc[df['preg']==6.0,['age']]
# Out:
#      age
# 0     50
# 33    28
# 95    40
# 98    23
# 121   24
# 165   41
# 170   36
# 171   29
# 176   42
# 180   32
# 204   55
# 217   32
# 231   46
# 243   33
# 295   28
# 310   41
# 319   59
# 329   37
# 366   29
# 401   55
# 410   28
# 439   31
# 469   27
# 495   66
# 499   39
# 502   41
# 519   60
# 522   26
# 533   31
# 552   66
# 560   54
# 563   32
# 567   46
# 576   35
# 581   27
# 587   29
# 594   34
# 601   28
# 613   26
# 616   30
# 622   45
# 642   50
# 664   40
# 668   43
# 670   49
# 675   31
# 701   49
# 705   28
# 749   50
# 759   66

# %%
df3=df2.dropna()
df3
# Out:
#      plas  pres  skin  insu  mass   pedi  age            class
# 0     148    72    35     0  33.6  0.627   50  tested_positive
# 1      85    66    29     0  26.6  0.351   31  tested_negative
# 2     183    64     0     0  23.3  0.672   32  tested_positive
# 3      89    66    23    94  28.1  0.167   21  tested_negative
# 4     137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...    ...  ...              ...
# 763   101    76    48   180  32.9  0.171   63  tested_negative
# 764   122    70    27     0  36.8  0.340   27  tested_negative
# 765   121    72    23   112  26.2  0.245   30  tested_negative
# 766   126    60     0     0  30.1  0.349   47  tested_positive
# 767    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 8 columns]

# %%
df3.dropna(inplace=True,axis=1)
df3
# Out:
#      plas  pres  skin  insu  mass   pedi  age            class
# 0     148    72    35     0  33.6  0.627   50  tested_positive
# 1      85    66    29     0  26.6  0.351   31  tested_negative
# 2     183    64     0     0  23.3  0.672   32  tested_positive
# 3      89    66    23    94  28.1  0.167   21  tested_negative
# 4     137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...    ...  ...              ...
# 763   101    76    48   180  32.9  0.171   63  tested_negative
# 764   122    70    27     0  36.8  0.340   27  tested_negative
# 765   121    72    23   112  26.2  0.245   30  tested_negative
# 766   126    60     0     0  30.1  0.349   47  tested_positive
# 767    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 8 columns]

# %%
df3.dropna(inplace=True,how='all')
df3
# Out:
#      plas  pres  skin  insu  mass   pedi  age            class
# 0     148    72    35     0  33.6  0.627   50  tested_positive
# 1      85    66    29     0  26.6  0.351   31  tested_negative
# 2     183    64     0     0  23.3  0.672   32  tested_positive
# 3      89    66    23    94  28.1  0.167   21  tested_negative
# 4     137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...    ...  ...              ...
# 763   101    76    48   180  32.9  0.171   63  tested_negative
# 764   122    70    27     0  36.8  0.340   27  tested_negative
# 765   121    72    23   112  26.2  0.245   30  tested_negative
# 766   126    60     0     0  30.1  0.349   47  tested_positive
# 767    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 8 columns]

# %%
df3.dropna(inplace=True,how='all')
df3
# Out:
#      plas  pres  skin  insu  mass   pedi  age            class
# 0     148    72    35     0  33.6  0.627   50  tested_positive
# 1      85    66    29     0  26.6  0.351   31  tested_negative
# 2     183    64     0     0  23.3  0.672   32  tested_positive
# 3      89    66    23    94  28.1  0.167   21  tested_negative
# 4     137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...    ...  ...              ...
# 763   101    76    48   180  32.9  0.171   63  tested_negative
# 764   122    70    27     0  36.8  0.340   27  tested_negative
# 765   121    72    23   112  26.2  0.245   30  tested_negative
# 766   126    60     0     0  30.1  0.349   47  tested_positive
# 767    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 8 columns]

# %%
mv=df3['plas'].mean()
dfn=df3.fillna(mv)
print(dfn)
# Out:
#      plas  pres  skin  insu  mass   pedi  age            class
# 0     148    72    35     0  33.6  0.627   50  tested_positive
# 1      85    66    29     0  26.6  0.351   31  tested_negative
# 2     183    64     0     0  23.3  0.672   32  tested_positive
# 3      89    66    23    94  28.1  0.167   21  tested_negative
# 4     137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...    ...  ...              ...
# 763   101    76    48   180  32.9  0.171   63  tested_negative
# 764   122    70    27     0  36.8  0.340   27  tested_negative
# 765   121    72    23   112  26.2  0.245   30  tested_negative
# 766   126    60     0     0  30.1  0.349   47  tested_positive
# 767    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 8 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
tigar = np.linspace(-2*np.pi, 2*np.pi, 100)
print(tigar)
plt.plot(tigar, np.sin(tigar) ,color='black')
plt.title("sin(x)")
# Display p
# Out:
# [-6.28318531 -6.15625227 -6.02931923 -5.9023862  -5.77545316 -5.64852012
#  -5.52158709 -5.39465405 -5.26772102 -5.14078798 -5.01385494 -4.88692191
#  -4.75998887 -4.63305583 -4.5061228  -4.37918976 -4.25225672 -4.12532369
#  -3.99839065 -3.87145761 -3.74452458 -3.61759154 -3.4906585  -3.36372547
#  -3.23679243 -3.10985939 -2.98292636 -2.85599332 -2.72906028 -2.60212725
#  -2.47519421 -2.34826118 -2.22132814 -2.0943951  -1.96746207 -1.84052903
#  -1.71359599 -1.58666296 -1.45972992 -1.33279688 -1.20586385 -1.07893081
#  -0.95199777 -0.82506474 -0.6981317  -0.57119866 -0.44426563 -0.31733259
#  -0.19039955 -0.06346652  0.06346652  0.19039955  0.31733259  0.44426563
#   0.57119866  0.6981317   0.82506474  0.95199777  1.07893081  1.20586385
#   1.33279688  1.45972992  1.58666296  1.71359599  1.84052903  1.96746207
#   2.0943951   2.22132814  2.34826118  2.47519421  2.60212725  2.72906028
#   2.85599332  2.98292636  3.10985939  3.23679243  3.36372547  3.4906585
#   3.61759154  3.74452458  3.87145761  3.99839065  4.12532369  4.25225672
#   4.37918976  4.5061228   4.63305583  4.75998887  4.88692191  5.01385494
#   5.14078798  5.26772102  5.39465405  5.52158709  5.64852012  5.77545316
#   5.9023862   6.02931923  6.15625227  6.28318531]
# Text(0.5, 1.0, 'sin(x)')

# %%
import numpy as np
import matplotlib.pyplot as plt
overs = np.arange(5,50,5)
overs_a = np.arange(5,30,5)
runs_i = np.array([25,51,84,131,160,189,220,250,267])
runs_a = np.array([15,41,94,110,151])
wickets = np.array([12,32,96])
plt.plot(overs,runs_i,color='blue',label='India')
plt.plot(overs_a,runs_a,color='yellow',label = 'Aus')
plt.legend(loc='best')
plt.show()

# %%
sal = np.array([12000,60000,80000,76000])
wd = np.array([210,300,230,256])
years = [1,2]
bonus=[]
for i,j in zip(sal,wd):
 if j > 250:
  i = i+i*0.1
  bonus.append(i)
 else:
  i = i-i*0.1
  bonus.append(i)
print(bonus)
# Out:
# [10800.0, 66000.0, 72000.0, 83600.0]

# %%
import matplotlib.pyplot as plt
a = [230,560,780,127,128]
b = [200,160,270,127,400]
years = [1,2,3,4]
profit_a = [(a[i]-a[i-1]) for i in range(1,len(a))]
profit_b = [(b[i]-b[i-1]) for i in range(1,len(b))]
plt.subplot(2,1,2)
plt.plot(years,profit_a,color='hotpink',linewidth = '2',label =
'CompanyA',marker='.',ms='20',mec='k')
plt.subplot(2,1,1)
plt.plot(years,profit_b,color='black',linestyle='dotted',label =
'CompanyB',marker = 'H')
plt.show()

# %%
print(np.arcsin(1)) #sin^-1
print(np.arccos(1))
print(np.arctan(0))
# Out:
# 1.5707963267948966
# 0.0
# 0.0

# %%
a = np.array([23,56,78,12,45,89,10,89,34,89,23,77])
print(np.mean(a))
print(np.median(a))
a = np.array([23,56,78,12,45,89,10,89,34,89,23,77])
b = np.array([23,56,78,12,40,90,10,85,31,89,23,77])
print(np.var(a))
print(np.std(a))
print(np.corrcoef(a,b))
a = np.array([25,60,5,10])
labe = ["AIML","Python","Pandas","Numpy"]
plt.pie(a,labels = labe)
plt.show()
a = np.array([25,60,5,10])
labe = ["AIML","Python","Pandas","Numpy"]
explo = [0.2,0,0,0]
plt.pie(a,labels = labe,explode = explo,startangle = 180)
plt.show()
a = np.array([25,60,5,10])
labe = ["AIML","Python","Pandas","Numpy"]
explo = [0.3,0,0,0]
plt.pie(a,labels = labe,explode = explo,shadow=True)
plt.legend()
plt.show()
a = np.array([25,60,5,10])
labe = ["AIML","Python","Pandas","Numpy"]
color = ['pink','black','coral','yellow']
plt.pie(a,labels = labe,colors= color)
plt.legend()
plt.show()
# Out:
# 52.083333333333336
# 50.5
# 903.5763888888888
# 30.059547383300515
# [[1.        0.9981131]
#  [0.9981131 1.       ]]

# %%
a = np.array([25,60,5,10])
labe = ["AIML","Python","Pandas","Numpy"]
color = ['green','red','coral','yellow']
plt.pie(a,labels = labe,colors= color)
plt.legend()
plt.show()
