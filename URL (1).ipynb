# %%
 from bs4 import BeautifulSoup
import requests

# %%
pip install pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488493 sha256=e7b23e5a45a50a470fb51dbb79e3e295890c43f0f189e16e0134871d62e4611c
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# ...

# %%
url="https://www.javatpoint.com/list-of-marvel-movies-in-order"

# %%
page=requests.get(url)

# %%
soup=BeautifulSoup(page.text,'html')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-BMVLE5WY82"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-BMVLE5WY82');
# </script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><title>List of Marvel Movies in order - Javatpoint</title><link href="https://static.javatpoint.com/images/favicon2.png" rel="SHORTCUT ICON"/>
# ...

# %%
title=soup.find('title')
print(title)
# Out:
# <title>List of Marvel Movies in order - Javatpoint</title>

# %%
print(title.text)
# Out:
# List of Marvel Movies in order - Javatpoint

# %%
table = soup.find('table')
print(table)
# Out:
# <table style="width:100%;margin-bottom:5px"> <tr> <td> <div style="clear:both;float:left;width:230px;margin-top:15px;margin-left:10px;margin-right:10px"> <a href="https://www.javatpoint.com"><img alt="Javatpoint Logo" src="https://static.javatpoint.com/images/logo/jtp-logo3.png"/></a> </div> <div style="float:left;width:60%;"><script> (function() { var cx = '005383125436438536544:y1edweedxwi'; var gcse = document.createElement('script'); gcse.type = 'text/javascript'; gcse.async = true; gcse.src = 'https://cse.google.com/cse.js?cx=' + cx; var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(gcse, s); })();</script><gcse:search></gcse:search> </div> </td> </tr></table>

# %%
Headings = table.find_all('th')
print(Headings)
# Out:
# []

# %%
Header = [i.text for i in Headings]
print(Header)
# Out:
# []

# %%
import pandas as pd
df = pd.DataFrame(columns = Header)
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
rows = table.find_all('tr')
print(rows)
print(df.columns)
# Out:
# [<tr> <td> <div style="clear:both;float:left;width:230px;margin-top:15px;margin-left:10px;margin-right:10px"> <a href="https://www.javatpoint.com"><img alt="Javatpoint Logo" src="https://static.javatpoint.com/images/logo/jtp-logo3.png"/></a> </div> <div style="float:left;width:60%;"><script> (function() { var cx = '005383125436438536544:y1edweedxwi'; var gcse = document.createElement('script'); gcse.type = 'text/javascript'; gcse.async = true; gcse.src = 'https://cse.google.com/cse.js?cx=' + cx; var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(gcse, s); })();</script><gcse:search></gcse:search> </div> </td> </tr>]
# Index([], dtype='object')

# %%
ind=0
for i in rows[1:10]:
  row_data = i.find_all('td')
  every_row_data = [i.text for i in row_data]
  print(every_row_data)
  df.loc[ind] = every_row_data
  ind = ind+1

# %%
df.to_csv("fifa winner list.csv")
